# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)

# %%
##### Моча
games = pd.read_excel('C:/Users/User/Desktop/list.xlsx',sheet_name=[0,1,2,3,4,5], index_col = 0)
df1=pd.DataFrame(games[0])
df2=pd.DataFrame(games[1])
df3=pd.DataFrame(games[2])
df4=pd.DataFrame(games[3])
df5=pd.DataFrame(games[4])
df6=pd.DataFrame(games[5])

# %%
game1=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='A:I', nrows=15)
game1.insert(loc=9,column="Opponent Name",value="X3")
game1.rename(columns={'X3':'Opponent'},inplace=True)
game1
# Out:
#     Point Offense/Defense  GoodVibes  Opponent  Turnovers  Break Point starts  \
# 0       1         Offense          1         0        4.0    NaN     00:00:50
# 1       2         Defense          1         1        2.0    NaN     00:04:40
# 2       3         Offense          2         1        NaN    NaN     00:07:05
# 3       4         Defense          2         2        NaN    NaN     00:08:25
# 4       5         Offense          3         2        NaN    NaN     00:10:38
# 5       6         Defense          4         2        1.0    1.0     00:11:38
# 6       7         Defense          4         3        NaN    NaN     00:13:53
# 7       8         Offense          4         4        1.0    1.0     00:14:42
# 8       9         Offense          5         4        NaN    NaN     00:16:01
# 9      10         Defense          5         5        NaN    NaN     00:17:08
# 10     11         Offense          5         6        1.0    1.0     00:18:25
# ...

# %%
players1=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='L:AU', nrows=11)
players1.insert(loc=0, column="Opponent Name",value="X3")
players1
# Out:
#    Opponent Name Player  Passes Total  Passes Completed  Drops  \
# 0             X3     p1           3.0               2.0    0.0
# 1             X3     p2           1.0               1.0    0.0
# 2             X3     p3           2.0               2.0    0.0
# 3             X3     p4           8.0               8.0    0.0
# 4             X3     p5           8.0               7.0    1.0
# 5             X3     p6           6.0               6.0    0.0
# 6             X3     p7          15.0              12.0    3.0
# 7             X3     p8           5.0               5.0    0.0
# 8             X3     p9           8.0               8.0    0.0
# 9             X3    p10           3.0               3.0    0.0
# 10            X3    p11           5.9               5.4    0.4
#
#     Blocks by them  Pases Efficiency  Passes Received  Passes Lost  \
# 0              1.0          0.666667              3.0          0.0
# 1              0.0          1.000000              1.0          0.0
# ...

# %%
game2=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='A:I', nrows=19, sheet_name='vs Nova')
game2.insert(loc=9,column="Opponent Name",value="Nova")
game2.rename(columns={'Nova':'Opponent'},inplace=True)
game2
# Out:
#     Point Offense/Defense  GoodVibes  Opponent  Turnovers  Break Point starts  \
# 0       1         Offense          1         0        2.0    NaN     00:01:08
# 1       2         Defense          1         1        NaN    NaN     00:03:32
# 2       3         Offense          2         1        NaN    NaN     00:04:34
# 3       4         Defense          2         2        NaN    NaN     00:05:47
# 4       5         Offense          3         2        NaN    NaN     00:07:08
# 5       6         Defense          3         3        NaN    NaN     00:08:31
# 6       7         Offense          4         3        NaN    NaN     00:09:15
# 7       8         Defense          5         3        1.0    1.0     00:10:48
# 8       9         Defense          5         4        NaN    NaN     00:12:40
# 9      10         Offense          6         4        NaN    NaN     00:13:26
# 10     11         Defense          6         5        NaN    NaN     00:15:22
# ...

# %%
players2=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='L:AU', nrows=11, sheet_name='vs Nova')
players2.insert(loc=0, column="Opponent Name",value="Nova")
players2
# Out:
#    Opponent Name Player  Passes Total  Passes Completed  Drops  \
# 0           Nova     p1           2.0               2.0    0.0
# 1           Nova     p2           2.0               2.0    0.0
# 2           Nova     p3           6.0               6.0    0.0
# 3           Nova     p4          24.0              23.0    1.0
# 4           Nova     p5          29.0              28.0    1.0
# 5           Nova     p6          15.0              14.0    1.0
# 6           Nova     p7          30.0              30.0    0.0
# 7           Nova     p8           5.0               5.0    0.0
# 8           Nova     p9          14.0              13.0    1.0
# 9           Nova    p10           2.0               2.0    0.0
# 10          Nova    p11          12.9              12.5    0.4
#
#     Blocks by them  Pases Efficiency  Passes Received  Passes Lost  \
# 0                0          1.000000               11          0.0
# 1                0          1.000000                2          0.0
# ...

# %%
game3=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='A:I', nrows=14, sheet_name='vs Lynxes')
game3.insert(loc=9,column="Opponent Name",value="Lynxes")
game3.rename(columns={'Lynxes':'Opponent'},inplace=True)
game3
# Out:
#     Point Offense/Defense  GoodVibes  Opponent  Turnovers  Break Point starts  \
# 0       1         Offense          1         0        2.0    NaN     00:00:44
# 1       2         Defense          2         0        1.0    1.0     00:03:15
# 2       3         Defense          2         1        NaN    NaN     00:04:47
# 3       4         Offense          3         1        NaN    NaN     00:05:36
# 4       5         Defense          4         1        1.0    1.0     00:06:52
# 5       6         Defense          5         1        1.0    1.0     00:08:10
# 6       7         Defense          6         1        1.0    1.0     00:09:12
# 7       8         Defense          7         1        3.0    1.0     00:10:46
# 8       9         Defense          8         1        3.0    1.0     00:14:30
# 9      10         Defense          9         1        1.0    1.0     00:17:38
# 10     11         Defense          9         2        NaN    NaN     00:19:52
# ...

# %%
players3=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='L:AU', nrows=11,sheet_name='vs Lynxes')
players3.insert(loc=0, column="Opponent Name",value="Lynxes")
players3
# Out:
#    Opponent Name Player  Passes Total  Passes Completed  Drops  \
# 0         Lynxes     p1           1.0               1.0    0.0
# 1         Lynxes     p2           2.0               1.0    1.0
# 2         Lynxes     p3           4.0               4.0    0.0
# 3         Lynxes     p4           8.0               7.0    1.0
# 4         Lynxes     p5          10.0               9.0    1.0
# 5         Lynxes     p6           5.0               5.0    0.0
# 6         Lynxes     p7           8.0               7.0    1.0
# 7         Lynxes     p8           2.0               2.0    0.0
# 8         Lynxes     p9          11.0              11.0    0.0
# 9         Lynxes    p10           2.0               2.0    0.0
# 10        Lynxes    p11           5.3               4.9    0.4
#
#     Blocks by them  Pases Efficiency  Passes Received  Passes Lost  \
# 0                0             1.000              3.0          0.0
# 1                0             0.500              4.0          0.0
# ...

# %%
game4=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='A:I', nrows=15,sheet_name='vs Phoenix')
game4.insert(loc=9,column="Opponent Name",value="Phoenix")
game4.rename(columns={'Phoenix':'Opponent'},inplace=True)
game4
# Out:
#     Point Offense/Defense  GoodVibes  Opponent  Turnovers  Break Point starts  \
# 0       1         Offense          0         1        1.0    1.0     00:01:40
# 1       2         Offense          1         1        NaN    NaN     00:02:58
# 2       3         Defense          1         2        NaN    NaN     00:04:26
# 3       4         Offense          1         3        1.0    1.0     00:05:21
# 4       5         Offense          2         3        NaN    NaN     00:07:14
# 5       6         Defense          3         3        1.0    1.0     00:08:25
# 6       7         Defense          4         3        4.0    1.0     00:09:56
# 7       8         Defense          4         4        NaN    NaN     00:14:25
# 8       9         Offense          5         4        NaN    NaN     00:16:26
# 9      10         Defense          6         4        1.0    1.0     00:17:59
# 10     11         Defense          6         5        NaN    NaN     00:20:09
# ...

# %%
players4=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='L:AU', nrows=11, sheet_name='vs Phoenix')
players4.insert(loc=0, column="Opponent Name",value="Phoenix")
players4
# Out:
#    Opponent Name Player  Passes Total  Passes Completed  Drops  \
# 0        Phoenix     p1           5.0               5.0    0.0
# 1        Phoenix     p2           0.0               0.0    0.0
# 2        Phoenix     p3           4.0               4.0    0.0
# 3        Phoenix     p4          12.0              12.0    0.0
# 4        Phoenix     p5          16.0              16.0    0.0
# 5        Phoenix     p6          10.0               9.0    1.0
# 6        Phoenix     p7          12.0              10.0    2.0
# 7        Phoenix     p8           4.0               3.0    1.0
# 8        Phoenix     p9           6.0               6.0    0.0
# 9        Phoenix    p10           2.0               2.0    0.0
# 10       Phoenix    p11           7.1               6.7    0.4
#
#     Blocks by them  Pases Efficiency  Passes Received  Passes Lost  \
# 0                0          1.000000              6.0          0.0
# 1                0          0.000000              0.0          0.0
# ...

# %%
game5=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='A:I', nrows=15, sheet_name='vs Executors')
game5.insert(loc=9,column="Opponent Name",value="Executors")
game5.rename(columns={'Executors':'Opponent'},inplace=True)
game5
# Out:
#     Point Offense/Defense  GoodVibes  Opponent  Turnovers  Break Point starts  \
# 0       1         Defense          0         1        NaN    NaN     00:05:59
# 1       2         Offense          0         2        1.0    1.0     00:07:18
# 2       3         Offense          0         3        1.0    1.0     00:09:03
# 3       4         Offense          1         3        NaN    NaN     00:10:05
# 4       5         Defense          2         3        1.0    1.0     00:11:16
# 5       6         Defense          2         4        2.0    NaN     00:12:53
# 6       7         Offense          3         4        NaN    NaN     00:14:27
# 7       8         Defense          4         4        1.0    1.0     00:15:28
# 8       9         Defense          4         5        NaN    NaN     00:17:09
# 9      10         Offense          4         6        5.0    NaN     00:18:43
# 10     11         Offense          4         7        1.0    1.0     00:25:12
# ...

# %%
players5=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='L:AU', nrows=12, sheet_name='vs Executors')
players5.insert(loc=0, column="Opponent Name",value="Executors")
players5
# Out:
#    Opponent Name    Player  Passes Total  Passes Completed     Drops  \
# 0      Executors        p1      5.000000                 5  0.000000
# 1      Executors        p2      1.000000                 0  1.000000
# 2      Executors        p3      2.000000                 2  0.000000
# 3      Executors        p4     10.000000                 9  1.000000
# 4      Executors        p5     23.000000                18  5.000000
# 5      Executors        p6      6.000000                 5  1.000000
# 6      Executors        p7      8.000000                 8  0.000000
# 7      Executors        p8      1.000000                 1  0.000000
# 8      Executors        p9      8.000000                 7  1.000000
# 9      Executors       p10      3.000000                 2  1.000000
# 10     Executors       p11     11.000000                 9  2.000000
# 11     Executors  Авокадий      7.090909                 6  1.090909
#
#     Blocks by them  Pases Efficiency  Passes Received  Passes Lost  \
# ...

# %%
game6=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='A:I', nrows=19,  sheet_name='vs Ultim8')
game6.insert(loc=9,column="Opponent Name",value="Ultim8")
game6.rename(columns={'Ultim8':'Opponent'},inplace=True)
game6
# Out:
#     Point Offense/Defense  GoodVibes  Opponent  Turnovers  Break Point starts  \
# 0       1         Offense          1         0        NaN    NaN     00:00:35
# 1       2         Defense          1         1        NaN    NaN     00:01:15
# 2       3         Offense          2         1        NaN    NaN     00:02:53
# 3       4         Defense          2         2        NaN    NaN     00:04:07
# 4       5         Offense          3         2        NaN    NaN     00:04:45
# 5       6         Defense          3         3        NaN    NaN     00:06:27
# 6       7         Offense          4         3        NaN    NaN     00:07:21
# 7       8         Defense          4         4        NaN    NaN     00:08:11
# 8       9         Offense          4         5        1.0    1.0     00:09:11
# 9      10         Offense          4         6        1.0    1.0     00:10:23
# 10     11         Offense          5         6        NaN    NaN     00:12:10
# ...

# %%
players6=pd.read_excel('C:/Users/User/Desktop/list.xlsx',usecols='L:AU', nrows=12, sheet_name='vs Ultim8')
players6.insert(loc=0, column="Opponent Name",value="Ultim8")
players6
# Out:
#    Opponent Name    Player  Passes Total  Passes Completed     Drops  \
# 0         Ultim8        p1      3.000000                 3  0.000000
# 1         Ultim8        p2      1.000000                 1  0.000000
# 2         Ultim8        p3      1.000000                 1  0.000000
# 3         Ultim8        p4     11.000000                10  1.000000
# 4         Ultim8        p5     16.000000                15  1.000000
# 5         Ultim8        p6      8.000000                 7  1.000000
# 6         Ultim8        p7     17.000000                17  0.000000
# 7         Ultim8        p8      3.000000                 3  0.000000
# 8         Ultim8        p9      9.000000                 8  1.000000
# 9         Ultim8       p10      0.000000                 0  0.000000
# 10        Ultim8       p11     12.000000                12  0.000000
# 11        Ultim8  Авокадий      7.363636                 7  0.363636
#
#     Blocks by them  Pases Efficiency  Passes Received  Passes Lost  \
# ...

# %%
gamesall=pd.concat([game1,game2,game3,game4,game5,game6],ignore_index=True)
gamesall
# Out:
#     Point Offense/Defense  GoodVibes  Opponent  Turnovers  Break Point starts  \
# 0       1         Offense          1         0        4.0    NaN     00:00:50
# 1       2         Defense          1         1        2.0    NaN     00:04:40
# 2       3         Offense          2         1        NaN    NaN     00:07:05
# 3       4         Defense          2         2        NaN    NaN     00:08:25
# 4       5         Offense          3         2        NaN    NaN     00:10:38
# 5       6         Defense          4         2        1.0    1.0     00:11:38
# 6       7         Defense          4         3        NaN    NaN     00:13:53
# 7       8         Offense          4         4        1.0    1.0     00:14:42
# 8       9         Offense          5         4        NaN    NaN     00:16:01
# 9      10         Defense          5         5        NaN    NaN     00:17:08
# 10     11         Offense          5         6        1.0    1.0     00:18:25
# ...

# %%
gamesall[gamesall["Point"]==3]
# Out:
#     Point Offense/Defense  GoodVibes  Opponent  Turnovers  Break Point starts  \
# 2       3         Offense          2         1        NaN    NaN     00:07:05
# 17      3         Offense          2         1        NaN    NaN     00:04:34
# 36      3         Defense          2         1        NaN    NaN     00:04:47
# 50      3         Defense          1         2        NaN    NaN     00:04:26
# 65      3         Offense          0         3        1.0    1.0     00:09:03
# 80      3         Offense          2         1        NaN    NaN     00:02:53
#
#    Point ends  Duration Opponent Name
# 2    00:07:53  00:00:48            X3
# 17   00:05:07  00:00:33          Nova
# 36   00:05:00  00:00:13        Lynxes
# 50   00:04:41  00:00:15       Phoenix
# 65   00:09:26  00:00:23     Executors
# 80   00:03:25  00:00:32        Ultim8
